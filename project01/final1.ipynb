# %%
from tkinter import *
from tkinter import ttk
from PIL import ImageTk, Image
from tkinter import messagebox
import tkinter.scrolledtext as tkst
import sqlite3

root = Tk()
root.title('mainpage')
root.geometry("400x400")
root.configure(bg='#D980FA')

Label(root, text = "An email has just sent by her!", font=('Helvetica',15,'bold'), fg='white', bg='#D980FA', pady=10).pack()
my_img = ImageTk.PhotoImage(Image.open('email3.gif'))
Label(image = my_img).pack()

def popup():
    response = messagebox.askyesno("Confirmation", "Are you sure?")
    if response == 1:
        # login = Tk()
        login=Toplevel()
        login.title("Login")
        login.geometry("280x200")
        login.configure(bg='#D980FA')
        

        def clkLogin():
            if id.get() == "kim1234" and pw.get() == "1q2w3e4r" :
                listPage = Tk()
                listPage.title('encrypted mail')
                listPage.geometry("350x500+100+100")
                listPage.resizable(False, False)

                frame1=Frame(listPage,  bd=1, height=50, bg="#AC58FA")
                frame1.pack(side="top", fill="both", expand=False)

                frame2=Frame(listPage, relief="flat", bd=2, bg='#D980FA')
                frame2.pack(side="bottom", fill="both", expand=True)

                def mail(event):
                    mail = Toplevel()
                    mail.title('encrypted mail')
                    mail.geometry("350x500+100+100")
                    mail.resizable(False, False)


                    msg = '읹 쓵렍긵얁& 폎샢 귽렌겑 삹앉랁3 헩얹젽'

                    def decode():
                        result=""
                        for i in msg:
                            if i not in (' '):
                                i=chr(ord(i)-5)
                                result+=i
                            else:
                                result+=' '
                        contents.insert(INSERT, result)


                    def reply():
                        reply = Tk()
                        reply.title("Reply")
                        reply.geometry("400x600")

                        conn = sqlite3.connect('reply.db')

                        c = conn.cursor()

                        # c.execute("""CREATE TABLE letter (
                        #         fromName text,
                        #         toName text,
                        #         address text,
                        #         contents text
                        #         )""")
                        def submit():

                            conn = sqlite3.connect('reply.db')

                            c = conn.cursor()

                            c. execute("INSERT INTO letter VALUES(:fromName, :toName, :address, :contents)",
                                    {
                                        'fromName':fromName.get(),
                                        'toName':toName.get(),
                                        'address':address.get(),
                                        'contents':contents.get()
                                    })

                            conn.commit()
                            conn.close()

                            fromName.delete(0, END)
                            toName.delete(0, END)
                            address.delete(0, END)
                            contents.delete(0, END)
                        
                        def query():
                            conn = sqlite3.connect('reply.db')
                            c = conn.cursor()
                            
                            c.execute("SELECT *, oid FROM letter")
                            records = c.fetchall()

                            print_records = ''
                            for record in records:
                                print_records += str(record) + " " "\n"

                            query_label = Label(reply, text = print_records)
                            # query_label.grid(row = 6, columnspan = 2)
                            query_label.grid(row = 6, columnspan = 2)

                            conn.commit()
                            conn.close()
                            return

                        def delete():
                                #database 또는 연결할 것 생성
                            conn = sqlite3.connect('reply.db')

                            #커서 생성
                            c = conn.cursor()

                            c.execute("DELETE from letter WHERE oid = " + delete_box.get())

                            #커밋 변경
                            conn.commit()

                            #연결 해제
                            conn.close()

                        def last():
                            response = messagebox.askyesno("Final Question", "종료하시겠습니까?")
                            if response == 1:
                                reply.destroy()
                                mail.destroy()

                                listPage.destroy()
                                login.destroy()
                                root.destroy()
                            else:
                                pass

                        fromName = Entry(reply, width = 30)
                        fromName.grid(row = 0, column = 1, padx = 20, pady = (10, 0))

                        toName = Entry(reply, width = 30)
                        toName.grid(row = 1, column = 1)

                        address = Entry(reply, width = 30)
                        address.grid(row = 2, column = 1)

                        contents = Entry(reply, width = 30)
                        contents.grid(row = 3, column = 1, padx = 10, pady = 10, ipadx = 20, ipady = 30)

                        fromName_label = Label(reply, text = "From")
                        fromName_label.grid(row = 0, column = 0, pady = (10,0))

                        toName_label = Label(reply, text = "To")
                        toName_label.grid(row = 1, column = 0)

                        address_label = Label(reply, text = "Address")
                        address_label.grid(row = 2, column = 0)

                        contents_label = Label(reply, text = "Contents")
                        contents_label.grid(row = 3, column = 0)

                        submit_btn = Button(reply, text = "Send a Mail", command = submit)
                        submit_btn.grid(row = 4, column = 0, columnspan = 2, pady = 10, padx = 10, ipadx = 100)

                        query_btn = Button(reply, text = "Show Mail", command = query)
                        query_btn.grid(row = 5, column = 0, columnspan = 2, pady = 10, padx = 10, ipadx = 137)

                        delte_box_label = Label(reply, text = "select id")
                        delte_box_label.grid(row = 9, column = 0, pady = 5)

                        delete_btn = Button(reply, text = "Delete Record", command = delete)
                        delete_btn.grid(row = 10, column = 0, columnspan = 2, pady = 10, padx = 10, ipadx = 136)

                        last_btn = Button(reply, text = "종료", command = last)
                        last_btn.grid(row = 11, column = 0, columnspan = 2, pady = 10, padx = 10, ipadx = 135)

                        conn.commit()
                        conn.close()

                        reply.mainloop()

                    text = Text(mail)
                    text.insert(INSERT, msg)
                    text.place(x=10, y=30, width=320, height=150)

                    scroll_y = Scrollbar(text, orient="vertical", command=text.yview)
                    scroll_y.pack(side="right", expand=False, fill="y")
                    text.configure(yscrollcommand=scroll_y.set)


                    btn_dec = Button(mail, text = '해독', command=decode, overrelief="solid", width=40, height=2, bg="#819FF7")
                    btn_dec.place(x=10, y=200, width=320, height=40)

                    contents = tkst.ScrolledText(mail, width=33, height=3, wrap=WORD)
                    contents.place(x=10, y=260, width=320, height=150)

                    btn_list = Button(mail, text = '편지목록', command=clkLogin, overrelief="solid", width=10, height=2, bg="#819FF7")
                    btn_list.place(x=10, y=430, width=100, height=40)

                    btn_write = Button(mail, text = '답장하기', command=reply, overrelief="solid", width=10, height=2, bg="#819FF7")
                    btn_write.place(x=230, y=430, width=100, height=40)

                    mail.mainloop()


                values=["메일 리스트", "작성 중인 메일", "보낸 메일", "수신 완료 메일"] 
                combobox= ttk.Combobox(frame1, values=values)
                combobox.place(x=70, y=15)
                combobox.set("메일 리스트")

                listbox = Listbox(frame2, selectmode='extended', width=30, height=20, activestyle="dotbox")
                listbox.insert(0, "김희애님의 메일")
                listbox.insert(1, "오정연님의 메일")
                listbox.insert(2, "이규형님의 메일")
                listbox.insert(3, "박서준님의 메일")
                listbox.insert(4, "박해준님의 메일")
                listbox.place(x=30, y=20)
                listbox.bind('<Double-1>', mail)

                listPage.mainloop()
            
        login_icon=ImageTk.PhotoImage(Image.open("user.gif"))
        login_icon_label=Label(login, image = login_icon)
        login_icon_label.grid(row = 0, column=1, pady=10)

        id_label = Label(login, text = "ID", bg='#D980FA', font=('Helvetica',12,'bold'), fg='white', padx=5)
        id_label.grid(row=1, column=0)
        id = Entry(login, width=30)
        id.grid(row=1, column=1)

        pw_label = Label(login, text = "PW", bg='#D980FA', font=('Helvetica',12,'bold'), fg='white', padx=5)
        pw_label.grid(row=2, column=0)
        pw = Entry(login, width=30, show='*')
        pw.grid(row=2, column=1)

        btn1 = Button(login, text = "Login", command = clkLogin)
        btn1.grid(row=3, column=1, pady=10)

        login.mainloop()

    else:
        root.destroy()

startBtn = Button(root, text = "Open", command = popup).pack()
root.mainloop()

# %%
# Out:
# '읹 쓵렍긵얁& 폎샢 귽렌겑 삹앉랁3 헩얹젽'
